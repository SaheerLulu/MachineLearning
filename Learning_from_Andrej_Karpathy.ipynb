# %% [markdown]
# <a href="https://colab.research.google.com/github/SaheerLulu/MachineLearning/blob/main/Learning_from_Andrej_Karpathy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Saheer")
# Out:
# Saheer

# %%
import pandas

# %%
import math
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def f(x):
  return  3*x**2 - 4*x + 5

# %%
f(3)
# Out:
# 20

# %%
xs = np.arange( -5,5, 0.25)
xs
# Out:
# array([-5.  , -4.75, -4.5 , -4.25, -4.  , -3.75, -3.5 , -3.25, -3.  ,
#        -2.75, -2.5 , -2.25, -2.  , -1.75, -1.5 , -1.25, -1.  , -0.75,
#        -0.5 , -0.25,  0.  ,  0.25,  0.5 ,  0.75,  1.  ,  1.25,  1.5 ,
#         1.75,  2.  ,  2.25,  2.5 ,  2.75,  3.  ,  3.25,  3.5 ,  3.75,
#         4.  ,  4.25,  4.5 ,  4.75])

# %%
ys = f(xs)
ys
# Out:
# array([100.    ,  91.6875,  83.75  ,  76.1875,  69.    ,  62.1875,
#         55.75  ,  49.6875,  44.    ,  38.6875,  33.75  ,  29.1875,
#         25.    ,  21.1875,  17.75  ,  14.6875,  12.    ,   9.6875,
#          7.75  ,   6.1875,   5.    ,   4.1875,   3.75  ,   3.6875,
#          4.    ,   4.6875,   5.75  ,   7.1875,   9.    ,  11.1875,
#         13.75  ,  16.6875,  20.    ,  23.6875,  27.75  ,  32.1875,
#         37.    ,  42.1875,  47.75  ,  53.6875])

# %%
#Now I am plotting above function
plt.plot(xs,ys)

# %%
#Now I want to find derivative of the above function

# so the derivative 2*3*x - 4

# %%
def derv(x):
  return 6*x - 4

# %%
ds = derv(xs)

# %%
plt.plot(xs,ds)

# %%
"""
Now using the definitin

derivation of function  = limit h -> 0 (f(a+h) - f(a))/h

"""
# Out:
# '\nNow using the definitin\n\nderivation of function  = limit h -> 0 (f(a+h) - f(a))/h\n\n'

# %%
h = 0.0000001
x = 20
(f(x+h) - f(x))/h
# Out:
# 116.0000010713702

# %%
h = 0.000001
x = 20
(f(x+h) - f(x))/h
# Out:
# 116.00000311773329

# %%
derv(20)
# Out:
# 116

# %%
# the above dervative by definition and methematical formula is same

# %%
derv(2/3) #local minima
# Out:
# 0.0

# %%
h = 0.000001
x = 2/3
(f(x+h) - f(x))/h
# Out:
# 2.999378523327323e-06

# %%
# lets get more complex

# %%
a =2
b = -3
c = 10
d = a*b + c
print(d)
# Out:
# 4

# %%
h = 0.000001
# inputs
a =2
b = -3
c =10

d1 = a*b + c

# now derivative d1 with respect to a

a += h
d2 = a*b + c

print('d1',d1)
print('d2',d2)
print('slope or derivative', (d2-d1)/h)
# Out:
# d1 4
# d2 3.9999969999999996
# slope or derivative -3.000000000419334

# %%
h = 0.000001
# inputs
a =2
b = -3
c =10

d1 = a*b + c

# now derivative d1 with respect to b

b += h
d2 = a*b + c

print('d1',d1)
print('d2',d2)
print('slope or derivative', (d2-d1)/h)
# Out:
# d1 4
# d2 4.000002
# slope or derivative 2.000000000279556

# %%
h = 0.000001
# inputs
a =2
b = -3
c =10

d1 = a*b + c

# now derivative d1 with respect to c

c += h
d2 = a*b + c

print('d1',d1)
print('d2',d2)
print('slope or derivative', (d2-d1)/h)
# Out:
# d1 4
# d2 4.000000999999999
# slope or derivative 0.9999999992515995

# %%
# from the above you can understand by changing each input, how it is affecting the functions

# %%
#now creating value class

class Value:

  def __init__(self,data):
    self.data = data

  def __repr__(self):
    return f"Value(data={self.data})"

# %%
a = Value(2.0)
a
# Out:
# Value(data=2.0)

# %%
b = Value (3.0)

# %%
b
# Out:
# Value(data=3.0)

# %%
 a+b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-ca730b97bf8a> in <cell line: 1>()
# ----> 1 a+b
#
# TypeError: unsupported operand type(s) for +: 'Value' and 'Value'

# %%
class Value:

  def __init__(self,data):
    self.data = data

  def __repr__(self):
    return f"Value(data={self.data})"

  def __add__(self,other):
    out = Value(self.data + other.data)
    return out

  def __mul__(self,other):
    out = Value(self.data * other.data)
    return out

# %%
a = Value(2.0)
b = Value (3.0)
a+b
# Out:
# Value(data=5.0)

# %%
c = Value(10.0)

# %%
a*c+b
# Out:
# Value(data=23.0)

# %%
#now I want to get the child or path of above function , so I modify the above class to show it

# %%
class Value:

  def __init__(self,data,_children=(),_op= '',label=''):
    self.data = data
    self._prev = set(_children)
    self._op = _op
    self.label = label

  def __repr__(self):
    return f"Value(data={self.data})"

  def __add__(self,other):
    out = Value(self.data + other.data,(self,other),"+")
    return out

  def __mul__(self,other):
    out = Value(self.data * other.data,(self,other),"*")
    return out

# %%
a = Value(2.0,label ='a')
b = Value (3.0,label ='b')
c = Value(10.0, label = 'c')
d = a*c+b;d.label ='d'

# %%
d
# Out:
# Value(data=23.0)

# %%
d._prev
# Out:
# {Value(data=20.0), Value(data=3.0)}

# %%
d._op
# Out:
# '+'

# %%
#Below I am creating function to know the process of addition

# %%
import graphviz
dot = graphviz.Digraph(comment='The Round Table')

# %%
dot.node('A', 'King Arthur')
dot.node('B', 'Sir Bedevere the Wise')
dot.node('L', 'Sir Lancelot the Brave')

# %%
dot

# %%
dot.edges(['AB', 'AL'])

# %%
dot

# %%
from graphviz import Digraph

def  trace(root):
  nodes, edges = set(),set()

  def build(v):
    if v not in nodes:
      nodes.add(v)
      for child in v._prev:
        edges.add((child,v))
        build(child)

  build(root)
  return nodes,edges


def draw_dot(root):
  dot = Digraph(format='svg',graph_attr={'rankdir':"LR"})
  nodes, edges = trace(root)

  for n in nodes:
    uid = str(id(n))
    dot.node(name=uid, label = "{%s | data %.4f} " %(n.label,n.data), shape = 'record')

    if n._op:
      dot.node(name= uid+n._op, label = n._op)
      dot.edge(uid+n._op, uid)

  for n1,n2 in edges:
    dot.edge(str(id(n1)),str(id(n2))+n2._op)

  return dot

# %%
draw_dot(d)
